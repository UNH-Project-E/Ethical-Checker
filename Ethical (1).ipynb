# %% [markdown]
# # Installs

# %%
pip install -U sentence-transformers
# Out:
# ...
#      |████████████████████████████████| 81kB 3.6MB/s
# ...
#      |████████████████████████████████| 2.1MB 6.9MB/s
# ...
#      |████████████████████████████████| 1.2MB 18.4MB/s
# ...
#      |████████████████████████████████| 870kB 40.3MB/s
# ...
#      |████████████████████████████████| 3.3MB 33.3MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-1.0.4-cp37-none-any.whl size=114307 sha256=71ce0ead8e289fcacd6b81d60fdac499304977e77f74b70f4dc7b101cea7523c
#   Stored in directory: /root/.cache/pip/wheels/26/ea/89/d0d2e013d951b6d23270aa9ca4018b82632ab7cd933c331316
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=0eac08bdd14db2f1b8b399a79763dd8f58c1feed73a63180ce7371816e5d9968
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sentence-transformers sacremoses
# ...

# %%
pip install pdfminer.six
# Out:
# ...
#      |████████████████████████████████| 5.6MB 4.1MB/s
# ...
#      |████████████████████████████████| 3.2MB 35.6MB/s
# ...

# %%
pip install transformers torch

# %%
pip install bert-extractive-summarizer

# %%
pip install sumy
# Out:
# ...
#      |████████████████████████████████| 92kB 3.2MB/s
# ...
#      |████████████████████████████████| 10.1MB 24.6MB/s
# ...
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21680 sha256=e65f017b674ced298f7ea32e383247b25b317b62c783e93afb94b08bfbeb7eab
#   Stored in directory: /root/.cache/pip/wheels/5a/4d/a1/510b12c5e65e0b2b3ce539b2af66da0fc57571e528924f4a52
# ...
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746863 sha256=ecfb9a0686789ba94fa1e9cd50e940a80a49ab74bcddc8851d4ae0c87727ef79
#   Stored in directory: /root/.cache/pip/wheels/33/4e/a6/be297e6b83567e537bed9df4a93f8590ec01c1acfbcd405348
# Successfully built breadability pycountry
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pip install requests

# %%
pip install bs4

# %%
pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 3.5MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp37-none-any.whl size=61085 sha256=b57b57861fc05cad930b5810f8d41db2650859533f5b02c42ad8dd9e622fbc04
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
pip install newspaper3k
# Out:
# ...
#      |████████████████████████████████| 215kB 4.4MB/s
# ...
#      |████████████████████████████████| 92kB 5.1MB/s
# ...
#      |████████████████████████████████| 81kB 5.3MB/s
# ...
#      |████████████████████████████████| 7.4MB 10.6MB/s
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-cp37-none-any.whl size=13538 sha256=30b4a303249b8e4bd1b63738e1cd358a0ae0749514a49661f3c8ba8f69868a8a
#   Stored in directory: /root/.cache/pip/wheels/81/2b/43/a02ede72324dd40cdd7ca53aad718c7710628e91b8b0dc0f02
# ...
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-cp37-none-any.whl size=7398406 sha256=cc0934733a8330771e484def9585c3688fbda895005effffc61f24831687d70f
#   Stored in directory: /root/.cache/pip/wheels/83/15/9c/a3f1f67e7f7181170ad37d32e503c35da20627c013f438ed34
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-cp37-none-any.whl size=3358 sha256=8aaff3583fc130ddd7aae497e6a7bd3a15c4b55a37d4b89276643cab1558bb33
# ...

# %% [markdown]
# # Libraries

# %%
from nltk.cluster.util import cosine_distance
import pandas as pd
import numpy as np
import networkx as nx
from nltk.tokenize import sent_tokenize
from sentence_transformers import SentenceTransformer
import requests
from bs4 import BeautifulSoup
import os
from os import listdir
from sumy.summarizers.lsa import LsaSummarizer

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
import PyPDF2
from PyPDF2 import PdfFileReader
from pdfminer.high_level import extract_text
import newspaper

# %%
import requests
#import RAKE
import operator
import timeit
import time
API_KEY = "AIzaSyAvZlAZHcE3lXigI2ZJxWQvCoCpF6qFiyY"
SEARCH_ENGINE_ID = "bf6585a79f0c6d8bb"

# %% [markdown]
# # Functions

# %%
def google_search(api_key, search_engine, query, page_number=1):
  start = (page_number - 1) * 10 + 1
  url = f"https://www.googleapis.com/customsearch/v1?key={api_key}&cx={search_engine}&q={query}&start={start}"
  data = requests.get(url).json()
  return data

# %%
def results(data):
  search_items = data.get("items")
  for i, search_item in enumerate(search_items, start=1):
    title = search_item.get("title")
    snippet = search_item.get("snippet")
    link = search_item.get("link")
    print("Title:", title)
    print("Description:", snippet)
    print("URL:", link, "\n")

# %%
def only_link(data):
  search_items = data.get("items")
  link=[]
  for i, search_item in enumerate(search_items, start=1):
    link.append(search_item.get("link")) 
    #print("URL:", link, "\n")
  return  link

# %%
def Sort (info):
  info.sort(key = lambda x: x[1], reverse=True)
  return info

# %%
def read_file(files):
  myfile = open(files, "r")
  readfiles=myfile.readlines()
  text =""
  for line in range(len(readfiles)):
    text = text + " "+ readfiles[line]
  return text

# %%
#building the similarity matrix
def sim_matrix(sentences, stop_words):
    length =len(sentences)
    sim_mat = np.zeros((length, length))
    for sen1 in range(length):
        for sen2 in range(length):
    # Create an empty similarity matrix
            if sen1 == sen2: 
                continue 
            sim_mat[sen1][sen2] = sentence_similarity(sentences[sen1], sentences[sen2], stop_words)

    return sim_mat

# %%
def sentence_similarity(sent1, sent2, stopwords=None):
    if stopwords is None:
        stopwords = []
 
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
    all_words = list(set(sent1 + sent2))
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
 
    # build the vector for the first sentence
    for w in sent1:
        if w in stopwords:
            continue
        vector1[all_words.index(w)] += 1
 
    # build the vector for the second sentence
    for w in sent2:
        if w in stopwords:
            continue
        vector2[all_words.index(w)] += 1
 
    return 1 - cosine_distance(vector1, vector2)

# %%
def generate_summary(sentences,stop_words,top_n=5):
    summarize_text = []
    summarized_text =""
    sentence_similarity_martix = sim_matrix(sentences, stop_words)

    sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_martix)
    scores = nx.pagerank(sentence_similarity_graph)
    print(sentence_similarity_graph)
    ranked_sentence = sorted(((scores[i],s) for i,s in enumerate(sentences)), reverse=True)    
   # print("Indexes of top ranked_sentence order are ", ranked_sentence)    

    for i in range(top_n):
      summarized_text= summarized_text +" "+ ranked_sentence[i][1]

    return summarized_text

# %% [markdown]
# # Actual Using LSA Summarizer

# %%
# !mkdir new_folder

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
textatten = read_file("/content/Project_info/kkkk.txt")
sentencesAtten=sent_tokenize(textatten)

# %%
#Read all the txt files in my folder 
all_text=[]
database = " "
from os.path import isfile, join
onlyfiles = [f for f in listdir('/content/Project_info') if isfile(join("/content/Project_info", f))]
for i in range(len(onlyfiles)):
    textatten = read_file('/content/Project_info'+ '/' + onlyfiles[i])
    database = database+ " " +textatten
    all_text.append(textatten)

# %%
print(onlyfiles)
# Out:
# ['Arist.txt', 'Structural_bio.txt', 'jjlaw.txt', 'Neural.txt', 'webscraper.txt', 'SmartStoplist.txt', 'Attention.txt', 'kkkk.txt', 'shakesphere.txt', 'educational development.txt', 'nuclear.txt', 'TwoStage.txt', 'morals.txt', 'music.txt', 'Evolution.txt', 'humSym.txt', 'climate.txt', 'canal.txt', 'moralsandethics.txt', 'earth.txt', 'fullmoon.txt']

# %%
print(len(onlyfiles))
# Out:
# 20

# %% [markdown]
# # User Requirement 3 -- Finding Similar Document

# %%
parser = PlaintextParser.from_string(textatten,Tokenizer("english"))
summarizer_lsa = LsaSummarizer()
# Summarize using sumy LSA
summary =summarizer_lsa(parser.document,2)
lsa_summary=""
for sentence in summary:
    lsa_summary+=str(sentence)  
print(lsa_summary)
# Out:
# For high similarity values, the overlap is much bigger than expected by chance as in 10 random permutation cases.Full size image Shared symptoms indicate shared genes between diseases We integrated three genotype–phenotype databases, yielding 28,336 disease–gene associations (Supplementary Methods, Supplementary Data 6) and constructed a Human Disease Network as described in Goh et al.13, in which two diseases are connected if they share an associated gene.

# %%
#myquery= input("Please enter the information to be searched ")
data =google_search(API_KEY,SEARCH_ENGINE_ID,lsa_summary)
results(data)
#print(data)
# Out:
# Title: Human symptoms–disease network | Nature Communications
# Description: Jun 26, 2014 ... Here, Zhou et al.link diseases via their symptom overlap, and show that similar ...
# Full size image ... For high similarity values, the overlap is much bigger than
# expected by ... Shared symptoms indicate shared genes between diseases. We
# integrated three genotype–phenotype databases, yielding 28,336 ...
# URL: https://www.nature.com/articles/ncomms5212
#
# Title: (PDF) Human symptoms–disease network
# Description: Jun 26, 2014 ... For high similarity values, the overlap is much bigger than expected by chance as
# in 10 ... Random expectation is derived from 10 random permutations, error bars
# denote s.d. (b) ... Shared symptoms indicate shared genes between diseases.
# We integrated three genotype–phenotype databases, yielding.
# URL: https://www.researchgate.net/publication/263430196_Human_symptoms-disease_network
#
# ...

# %% [markdown]
# With Generate Summ Function

# %%
summarised =generate_summary(sentencesAtten,'SmartStoplist.txt' ,3)
print(summarised)
# Out:
#  Performance of several techniques has been already reported on this set, including N-gram models, LSA-based model [32], log-bilinear model [24] and a combination of recurrent neural networks that currently holds the state of the art performance of 55.4% accuracy on this benchmark [19]. However, several practical solutions were proposed for avoiding it; either using hierarchical versions of the softmax [25, 23, 18], or avoiding normalized models completely by using models that are not normalized during training [4, 9]. The new architectures directly follow those proposed in our earlier work [13, 14], where it was found that neural network language model can be successfully trained in two steps: first, continuous word vectors are learned using simple model, and then the N-gram NNLM is trained on top of these distributed representations of words.

# %%
data =google_search(API_KEY,SEARCH_ENGINE_ID,summarised)
results(data)
# Out:
# Title: Efficient Estimation of Word Representations in Vector Space
# Description: Sep 7, 2013 ... Furthermore, we show that these vectors provide state-of-the-art perfor- ...
# However, the simple techniques are at their limits in many tasks. ... Recurrent
# neural network based language model has been ... been already reported on this
# set, including N-gram models, LSA-based model [32], log-bilinear model ...
# URL: https://arxiv.org/pdf/1301.3781
#
# Title: (PDF) Efficient Estimation of Word Representations in Vector Space
# Description: Oct 21, 2014 ... Many current NLP systems and techniques treat words as atomic units ...
# Recurrent neural network based language model has been proposed to ... been
# already reported on this set, including N-gram models, LSA-based model [32],
# log-bilinear ... performance of 55.4% accuracy on this benchmark [19].
# URL: https://www.researchgate.net/publication/234131319_Efficient_Estimation_of_Word_Representations_in_Vector_Space
#
# ...

# %% [markdown]
# # WebStripping

# %%
URL_link =only_link(data)
Extracted_pdf =[]
length=0
if len(URL_link)>2:
  length =2
else:
  length = len(URL_link)
for i in range(length):
  if URL_link[i].find("pdf")!=-1:
    response = requests.get(URL_link[i]) 
    pdf = open("pdf"+str(i)+".pdf", 'wb') 
    pdf.write(response.content) 
    pdf.close() 
    print("File ", i, " downloaded")
    text = extract_text("pdf"+str(i)+".pdf")
 
    #print(text)
    Extracted_pdf.append(text)
  
  else:
    try:
      Url_i = newspaper.Article(url="%s" % (URL_link[i]), language='en') 
      Url_i.download() 
      Url_i.parse() 
      Extracted_pdf.append(Url_i.text)
      print('Successful')
    except:
      print('something went wrong')
# Out:
# File  0  downloaded
# Successful

# %%
sentencesweb=sent_tokenize(text)
sentencesAtten=sent_tokenize(textatten)

# %% [markdown]
# # Document Similarity

# %%
#TRying without stripping
Extracted_pdf=all_text

# %%
Tokenized_Stripped=[]
for i in range(len(Extracted_pdf)):
  sentenceh=sent_tokenize(Extracted_pdf[i])
  Tokenized_Stripped.append(sentenceh)

# %%
sentencesweb=sent_tokenize(text)
sentencesAtten=sent_tokenize(textatten)
model = SentenceTransformer('bert-base-nli-mean-tokens')
text_embeddings = model.encode(sentencesweb, batch_size = 8, show_progress_bar = True)
text_embeddings2 = model.encode(sentencesAtten, batch_size = 8, show_progress_bar = True)
np.shape(text_embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-740227fbafcf> in <module>()
# ----> 1 sentencesweb=sent_tokenize(text)
#       2 sentencesAtten=sent_tokenize(textatten)
#       3 model = SentenceTransformer('bert-base-nli-mean-tokens')
#       4 text_embeddings = model.encode(sentencesweb, batch_size = 8, show_progress_bar = True)
#       5 text_embeddings2 = model.encode(sentencesAtten, batch_size = 8, show_progress_bar = True)
#
# NameError: name 'text' is not defined

# %% [markdown]
# # Trial 2

# %%
#Tokenizing the received
textevol = read_file("Evolution.txt")
sentencesevol=sent_tokenize(textevol)
textStruct = read_file("Structural_bio.txt")
sentencesStruct=sent_tokenize(textStruct)

# %%
parser = PlaintextParser.from_string(textStruct,Tokenizer("english"))
summarizer_lsa = LsaSummarizer()
# Summarize using sumy LSA
summary =summarizer_lsa(parser.document,2)
lsa_summary=""
for sentence in summary:
    lsa_summary+=str(sentencesStruct)  
print(lsa_summary)
# Out:
# [' Structural bioinformatics\n CLoNe: automated clustering based on local density\n neighborhoods for application to biomolecular structural\n ensembles\n Sylvain Tra¨ ger1,2, Giorgio Tamo` 1,2, Deniz Aydin1,2, Giulia Fonti1,2,\n Martina Audagnotto1,2 and Matteo Dal Peraro1,2,*\n 1\n Institute of Bioengineering, School of Life Sciences, Ecole Polytechnique Fe´ de´ rale de Lausanne, Lausanne 1025, Switzerland and 2\n Swiss Institute of Bioinformatics, Lausanne 1015, Switzerland\n *To whom correspondence should be addressed.', 'Associate Editor: Lenore Cowen\n Received on January 8, 2020; revised on July 14, 2020; editorial decision on August 12, 2020; accepted on August 18, 2020\n Abstract\n Motivation: Proteins are intrinsically dynamic entities.', 'Flexibility sampling methods, such as molecular dynamics or\n those arising from integrative modeling strategies, are now commonplace and enable the study of molecular conformational landscapes in many contexts.', 'Resulting structural en
# ...

# %%
lsa_summary[0]
# Out:
# '['

# %%
myquery= input("Please enter the information to be searched ")
data =google_search(API_KEY,SEARCH_ENGINE_ID,myquery)
results(data)
# Out:
# Please enter the information to be searched Structural bioinformatics\\n CLoNe: automated clustering based on local density\\n neighborhoods for application to biomolecular structural\\n ensembles\\n Sylvain Tra¨ ger1,2, Giorgio Tamo` 1,2, Deniz Aydin1,2, Giulia Fonti1,2,\\n Martina Audagnotto1,2 and Matteo Dal Peraro1,2,*\\n 1\\n Institute of Bioengineering, School of Life Sciences, Ecole Polytechnique Fe´ de´ rale de Lausanne, Lausanne 1025, Switzerland and 2\\n Swiss Institute of Bioinformatics, Lausanne 1015, Switzerland\\n *To whom correspondence should be addressed.', 'Associate Editor: Lenore Cowen\\n Received on January 8, 2020; revised on July 14, 2020; editorial decision on August 12, 2020; accepted on August 18, 2020\\n Abstract\\n Motivation: Proteins are intrinsically dynamic entities.', 'Flexibility sampling methods, such as molecular dynamics or\\n those arising from integrative modeling strategies, are now commonplace and enable the study of molecular conformational l
# ...

# %%
url = "https://academic.oup.com/bioinformatics/advance-article-pdf/doi/10.1093/bioinformatics/btaa742/36453399/btaa742.pdf  "

# Requests URL and get response object 
response = requests.get(url) 
i=1
pdf = open("pdf"+str(i)+".pdf", 'wb') 
pdf.write(response.content) 
pdf.close() 
print("File ", i, " downloaded")
# Out:
# File  1  downloaded

# %%
import PyPDF2
from PyPDF2 import PdfFileReader
  
# creating a pdf file object
pdfFileObj = open('pdf1.pdf', 'rb')
  
# creating a pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
with open("pdf1.pdf", 'rb') as f:
  pdf = PdfFileReader(f)
  information = pdf.getDocumentInfo()
  number_of_pages = pdf.getNumPages()

txt = f"""
Information about {"pdf1.pdf"}: 
Author: {information.author}
Creator: {information.creator}
Producer: {information.producer}
Subject: {information.subject}
Title: {information.title}
Number of pages: {number_of_pages}
    """

print(txt)
# Out:
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# <ipython-input-38-27542030cf8b> in <module>()
#       6
#       7 # creating a pdf reader object
# ----> 8 pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
#       9 with open("pdf1.pdf", 'rb') as f:
#      10   pdf = PdfFileReader(f)
#
# /usr/local/lib/python3.7/dist-packages/PyPDF2/pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
# -> 1084         self.read(stream)
#    1085         self.stream = stream
#    1086
#
# /usr/local/lib/python3.7/dist-packages/PyPDF2/pdf.py in read(self, stream)
#    1695             if stream.tell() < last1K:
#    1696                 raise utils.PdfReadError("EOF marker not found")
# -> 1697             line = self.readNextEndLine(stream)
# ...

# %%
import newspaper 
URL_link =only_link(data)
all_scraped_documents =[]  
i= 0
# Parse through each url and display its content 
for url in URL_link: 
    print("First Run")
    url_i = newspaper.Article(url="%s" % (url), language='en') 
    url_i.download() 
    url_i.parse() 
    all_scraped_documents.append(url_i.text)
    i = i+1
    print(url_i.text)
# Out:
# First Run
# ---------------------------------------------------------------------------
# ArticleException                          Traceback (most recent call last)
# <ipython-input-36-536ddf7c9619> in <module>()
#       8     url_i = newspaper.Article(url="%s" % (url), language='en')
#       9     url_i.download()
# ---> 10     url_i.parse()
#      11     all_scraped_documents.append(url_i.text)
#      12     i = i+1
#
# /usr/local/lib/python3.7/dist-packages/newspaper/article.py in parse(self)
#     189
#     190     def parse(self):
# --> 191         self.throw_if_not_downloaded_verbose()
#     192
#     193         self.doc = self.config.get_parser().fromstring(self.html)
#
# /usr/local/lib/python3.7/dist-packages/newspaper/article.py in throw_if_not_downloaded_verbose(self)
#     530         elif self.download_state == ArticleDownloadState.FAILED_RESPONSE:
#     531             raise ArticleException('Article `download()` failed with %s on URL %s' %
# ...

# %%
sentencesweb=sent_tokenize(textextract2)
text_embeddings = model.encode(sentencesweb, batch_size = 8, show_progress_bar = True)
text_embeddings2 = model.encode(sentencesAtten, batch_size = 8, show_progress_bar = True)
np.shape(text_embeddings)

# %%
similarities = cosine_similarity(text_embeddings,text_embeddings2)
similarities_sorted = similarities.argsort()
# Get list of similarity indices i.e. doc at index 0 simialr with doc at index 1169 below.
id_1 = []
id_2 = []
score = []
for index,array in enumerate(similarities_sorted):
    id_1.append(index)
    id_2.append(array[-2])
    score.append(similarities[index][array[-2]])

# %%
sum_of_sims =(np.sum(index_df["score"]))
print(sum_of_sims)
percentage_of_similarity = round(float((sum_of_sims / len(sentencesweb)) * 100))
print(f'Average similarity float: {float(sum_of_sims / len(sentencesweb))}')
print(f'Average similarity percentage: {float(sum_of_sims / len(sentencesweb)) * 100}')
print(f'Average similarity rounded percentage: {percentage_of_similarity}')

# %% [markdown]
# # User Requirement 2 - Document Similarity

# %%
#TRying without stripping
Extracted_pdf=all_text

# %%
Tokenized_Stripped=[]
for i in range(len(Extracted_pdf)):
  sentenceh=sent_tokenize(Extracted_pdf[i])
  Tokenized_Stripped.append(sentenceh)

# %%
test="Transformers are emerging as a natural alternative to standard RNNs, replacing recurrent computations with a multi-head attention mechanism."

# %%
model = SentenceTransformer('bert-base-nli-mean-tokens')
main_embeddings = model.encode(database, batch_size = 8, show_progress_bar = True)
Atten_embeddings2 = model.encode(sentencesAtten, batch_size = 8, show_progress_bar = True)

# %%
text_e = model.encode(test,batch_size = 8, show_progress_bar = True)

# %%
np.shape(text_e)
#thislength=3
for i in range(len(Tokenized_Stripped)):
  text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  np.shape(text_embeddings)
  sumed =0
  sim=cosine_similarity(Atten_embeddings2,text_embeddings)
  print(sim)
# Out:
# ...
# [[0.500082   0.37137625 0.43623024 ... 0.48375675 0.51301897 0.4210522 ]
#  [0.43521434 0.32533908 0.4915847  ... 0.41394514 0.4529869  0.4082212 ]
#  [0.30836746 0.20715374 0.3453316  ... 0.16718225 0.17059006 0.23658954]
#  ...
#  [0.31313607 0.27396828 0.13552256 ... 0.23644742 0.22339532 0.25536156]
#  [0.19243255 0.25778636 0.17841537 ... 0.05351097 0.06682938 0.12339282]
#  [0.42192668 0.2856015  0.34474605 ... 0.52286506 0.524611   0.5303823 ]]
# ...
# [[0.61137533 0.50334793 0.5590681  ... 0.42861474 0.24345231 0.47222167]
#  [0.45038384 0.4287166  0.4421792  ... 0.35247698 0.26418757 0.3700279 ]
#  [0.23704784 0.29900497 0.41122216 ... 0.3052108  0.31163636 0.19520469]
#  ...
#  [0.27419722 0.44222254 0.26739007 ... 0.42359257 0.55390227 0.3134383 ]
#  [0.14815582 0.39179793 0.2673242  ... 0.54934907 0.6104392  0.35462427]
#  [0.5270983  0.62573224 0.37934473 ... 0.4597299  0.2904395  0.583045  ]]
# ...
# [[0.15631491 0.2916274  0.26209372 ... 0.15963207 0.33075154 0.42604643]
# ...

# %%
np.sum(summ)/10778
# Out:
# 0.2634891206334663

# %%
 text_embeddingsAtt = model.encode(Tokenized_Stripped[6], batch_size = 8, show_progress_bar = True)

# %%
cosine_similarity(text_e.reshape(1,-1),text_embeddingsAtt)
# Out:
# array([[0.56764644, 0.49769983, 0.9999999 , 0.66037214, 0.67782265,
#         0.57601833, 0.363383  , 0.5618271 , 0.54577565, 0.53620666,
#         0.2937849 , 0.5228121 , 0.54698396, 0.46937585, 0.3376271 ,
#         0.6962118 , 0.6832021 , 0.4876876 , 0.35962626, 0.60703325,
#         0.49555498, 0.2937849 , 0.62512624, 0.531629  , 0.37772298,
#         0.66296047, 0.60611093, 0.6776063 , 0.53534055, 0.49375296,
#         0.67673516, 0.74293214, 0.7403908 , 0.78523713, 0.66101   ,
#         0.5669261 , 0.4115156 , 0.47162324, 0.46483123, 0.5983072 ,
#         0.26239556, 0.5790606 , 0.57871634, 0.58304083, 0.63465965,
#         0.3191596 , 0.4801163 , 0.6085659 , 0.36733362, 0.5431207 ,
#         0.26702848, 0.47982973, 0.50061095, 0.2565706 , 0.2565706 ,
#         0.39432934, 0.5457635 , 0.2185015 , 0.46731073, 0.44229442,
#         0.37142915, 0.6453258 , 0.5144559 , 0.363191  , 0.47021323,
#         0.467647  , 0.24626976, 0.47938403, 0.49323052, 0.6050861 ,
# ...

# %%
print(Tokenized_Stripped[6][2])
# Out:
# Transformers are emerging as a natural alternative to
#  standard RNNs, replacing recurrent computations with a multi-head
#  attention mechanism.

# %%
print(text_embeddingsAtt[1])
# Out:
# [ 1.47825822e-01  1.08827245e+00  7.78244197e-01  6.04122765e-02
#  -9.82216671e-02  7.08586648e-02  2.09459019e+00  4.97923255e-01
#   3.92835051e-01  3.64855289e-01 -5.73243380e-01  6.03947282e-01
#  -1.92880213e-01  7.83972204e-01  2.15592563e-01  2.80677527e-01
#   8.04441497e-02 -7.40464807e-01 -2.59758025e-01 -2.66662925e-01
#  -4.63076323e-01 -9.33516696e-02 -4.30731565e-01 -8.32081214e-02
#   7.28107914e-02 -4.14863199e-01 -4.48254542e-03 -5.50534964e-01
#  -1.16062331e+00  4.14513946e-01  3.89734767e-02  7.16293633e-01
#   9.18357849e-01  1.56822458e-01  7.34586358e-01  6.60083055e-01
#   6.51223958e-01 -3.71978372e-01 -2.64974553e-02 -5.21623254e-01
#   1.04578280e+00 -8.67994949e-02  1.87289938e-01 -1.00704767e-01
#  -9.34671164e-02  1.91160262e-01  1.51544678e+00 -9.87522602e-02
#  -4.75678109e-02 -2.66307533e-01 -7.58429945e-01  1.66419521e-01
#   1.11768639e+00  9.18708622e-01  2.33083546e-01 -6.04623914e-01
# ...

# %%
print(text_e)
# Out:
# [-1.52057782e-01 -1.47779182e-01  1.59675169e+00  2.89795280e-01
#   4.50343750e-02 -9.09184337e-01  3.79980765e-02 -4.99235779e-01
#   4.54506248e-01 -5.68483472e-01  1.24772176e-01  1.32582343e+00
#   1.09855957e-01  4.19149756e-01 -1.23701584e+00 -2.28308991e-01
#  -9.17394698e-01 -1.11334920e+00 -8.06861222e-02  3.89250182e-02
#  -3.96989770e-02 -1.36795491e-01 -2.92569757e-01  6.67948067e-01
#  -1.84120715e-01  8.02432150e-02  6.46640897e-01 -4.62300450e-01
#  -3.65363330e-01  3.49934965e-01 -1.66382685e-01  4.01627302e-01
#   2.43796781e-02 -8.04337204e-01 -3.98705453e-01  1.06476796e+00
#   3.69198054e-01 -4.55648214e-01  1.21473029e-01  3.52439463e-01
#   4.04998839e-01 -3.10239851e-01 -1.93403840e-01  1.09715648e-01
#  -1.47252560e+00  2.11378057e-02 -5.90250850e-01  5.70516288e-01
#  -4.84679669e-01 -8.21989179e-01 -8.94890368e-01 -7.79922083e-02
#  -4.17513311e-01  5.10202348e-02 -5.96515656e-01  9.15311649e-02
# ...

# %%
Tokenized_Stripped[9][8]
# Out:
# 'Image 1 of 3\n Three nuclear submarines owned by Russia maneuvered to break through several feet of Arctic ice at the same time.'

# %%
Tokenized_Stripped[6][5]
# Out:
# '1\tIntroduction\n Many current NLP systems and techniques treat words as atomic units - there is no notion of similarity between words, as these are represented as indices in a vocabulary.'

# %%
Tokenized_Stripped[0][5]
# Out:
# 'Finally, John Donne’s Holy Sonnet XII and Geoffrey Chaucer’s The Canterbury Tales impart decidedly anti-Semitic themes while alluding to the crucifixion of Jesus.'

# %%
#np.shape(text_e)
databasedict ={}
#thislength=3
for i in range(len(Tokenized_Stripped)):
  text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  np.shape(text_embeddings)
  databasedict[onlyfiles[i]]=text_embeddings
  sumed =0
  #sim=cosine_similarity([text_e],text_embeddings)
  #print(sim)

# %% [markdown]
# trying

# %%
textCit = read_file("citation.txt")
sentencesCit=sent_tokenize(textCit)

# %%
text_embedCit = model.encode(textCit, batch_size = 8, show_progress_bar = True)

# %%
onlyfiles
# Out:
# ['Arist.txt',
#  'Structural_bio.txt',
#  'jjlaw.txt',
#  'Neural.txt',
#  'webscraper.txt',
#  'SmartStoplist.txt',
#  'Attention.txt',
#  'kkkk.txt',
#  'shakesphere.txt',
#  'educational development.txt',
#  'nuclear.txt',
#  'TwoStage.txt',
#  'morals.txt',
#  'music.txt',
#  'Evolution.txt',
#  'humSym.txt',
#  'climate.txt',
#  'canal.txt',
#  'moralsandethics.txt',
#  'earth.txt',
#  'fullmoon.txt']

# %%
for i in databasedict.values():
  #text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  #np.shape(text_embeddings)
  #databasedict[onlyfiles[i]]=text_embeddings
  #sumed =0
  print('/n')
  print('line')
  sim=cosine_similarity([text_embedCit],i)
  print(sim)
# Out:
# /n
# line
# [[0.50370926 0.40397125 0.19670874 0.5506997  0.4683129  0.648975
#   0.52191114 0.5937376  0.58936936 0.5713487  0.4324297  0.61243916
#   0.6334089  0.6147966  0.5407609  0.47724125 0.5589023  0.5547146
#   0.62407595 0.5103978  0.45797956 0.549726   0.5930956  0.5893141
#   0.5699271  0.58542824 0.47948346 0.61033535 0.49537006 0.49249765
#   0.30806446 0.6138371  0.53133863 0.6125003  0.5441937  0.60635006
#   0.5231694  0.46790817 0.5377828  0.36742553 0.4364132  0.53970736
#   0.5945035  0.58948874 0.60267586 0.5119865  0.61743414 0.5279436
#   0.6002577  0.5116699  0.50249666 0.54758584 0.4836046  0.5903432
#   0.5957887  0.5430197  0.5320631  0.6023171  0.55864215 0.5216478
#   0.64135647 0.68240166 0.6711173  0.45561123 0.5811584  0.47361246
#   0.4813615  0.37413156 0.58290577 0.40604937 0.69486886 0.534399
#   0.47115043 0.24880654]]
# /n
# line
# [[ 0.43518692  0.4091164   0.17007177  0.23138095  0.10402798  0.32345933
# ...

# %%
print(sim)
# Out:
# [[0.5661872  0.3374996  0.574691   0.5319318  0.48343396 0.41211888
#   0.5746923  0.54130924 0.44985303 0.2233786  0.11931786 0.2605713
#   0.5227314  0.5227314  0.6190605  0.29164523 0.48830247 0.5597492
#   0.5597492  0.5311677  0.44800344 0.4361654  0.27533764 0.43934232
#   0.26153433 0.48419192 0.49470603 0.3864457  0.37201053 0.49238977
#   0.35150623 0.3268925  0.28372613 0.18550992]]

# %%
np.shape(text_e)
#thislength=3
for i in range(len(Tokenized_Stripped)):
  text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  np.shape(text_embeddings)
  sumed =0
  sim=cosine_similarity([text_e],text_embeddings)
  print(sim)
# Out:
# ...
# [[0.36714137 0.24988544 0.42904055 0.3059873  0.28943133 0.35502753
#   0.33431083 0.32036346 0.34571916 0.19844237 0.4187257  0.26487684
#   0.3118438  0.29268223 0.32937092 0.33769754 0.42029226 0.32107484
#   0.29652694 0.28733617 0.36921552 0.30640352 0.30780262 0.25183335
#   0.2360806  0.31511074 0.26112926 0.17748442 0.18685737 0.4334383
#   0.44757012 0.26312304 0.3223739  0.33924    0.35390037 0.30811495
#   0.2655289  0.35314947 0.32440546 0.25908726 0.35891408 0.35061085
#   0.3702619  0.28343698 0.23077305 0.33681226 0.29485655 0.42071903
#   0.3050876  0.18637145 0.24263684 0.3479171  0.2574744  0.17797908
#   0.22673437 0.28767377 0.26381177 0.2536532  0.26860437 0.22487909
#   0.26903784 0.3063487  0.35464793 0.3295655  0.23284882 0.23301639
#   0.35060227 0.19222754 0.3650462  0.1789091  0.27381486 0.3611351
#   0.35907066 0.33353347]]
# ...
# [[0.5903007  0.504529   0.5377203  0.44715518 0.5291923  0.5404011
# ...

# %%
test44 ="Anti-semitism is a prevailing cultural sentiment in Africa, particularly in Accra, during the period when some of Twi literature's most celebrated figures"

# %%
test44 ="During the period of Twi literature's most celebrated figures,Anti-sentism is a prevailing cultural sentiment in Africa"

# %%
onlyfiles[7]
# Out:
# 'kkkk.txt'

# %%
 text_embeddings44 = model.encode(test44, batch_size = 8, show_progress_bar = True)

# %%
Tokenized_Stripped[18][9]
# Out:
# 'Many people also inherit their morality from their family, community or culture – it’s rare for somebody to ‘shop around’ for the morality that most closely fits their personal beliefs.'

# %%
 text_embeddings447 = model.encode(Tokenized_Stripped[0], batch_size = 8, show_progress_bar = True)

# %%
cosine_similarity([text_embeddings44],text_embeddings447)
# Out:
# array([[0.6460258 , 0.542941  , 0.57357   , 0.51659644, 0.60146415,
#         0.5151427 , 0.60243964, 0.5444093 , 0.313645  , 0.48789406,
#         0.54099166, 0.5693718 , 0.4046803 , 0.6096828 , 0.4663766 ,
#         0.5042845 , 0.46195516, 0.58822376, 0.4947492 , 0.52044404,
#         0.61639637, 0.6158465 , 0.49733466, 0.4306336 , 0.54164743,
#         0.5392591 , 0.5591616 , 0.46975523, 0.47210544, 0.45986336,
#         0.64702   , 0.5857647 , 0.5785532 , 0.5086472 , 0.39113533,
#         0.4229282 , 0.5356719 , 0.5565119 , 0.55062014, 0.32833898,
#         0.4683092 , 0.4512902 , 0.5304565 , 0.42572704, 0.4599232 ,
#         0.58744156, 0.47959214, 0.474028  , 0.4401906 , 0.49743986,
#         0.615476  , 0.55799824, 0.43483567, 0.3628835 , 0.31846678,
#         0.47651058, 0.4106732 , 0.5851135 , 0.515224  , 0.54072654,
#         0.469741  , 0.44519365, 0.41643643, 0.5612191 , 0.5083868 ,
#         0.33719984, 0.5362853 , 0.5037774 , 0.5174217 , 0.49701065,
# ...

# %%
np.shape(text_e)
#thislength=3
for i in range(len(Tokenized_Stripped)):
  text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  np.shape(text_embeddings)
  sumed =0
  sim=cosine_similarity([text_embeddings44],text_embeddings)
  print(sim)
# Out:
# ...
# [[0.41375697 0.16254768 0.26457453 0.2630369  0.34190774 0.2769067
#   0.2804958  0.32570887 0.2508283  0.06780523 0.3069867  0.26985592
#   0.18099138 0.2851633  0.13820177 0.12953156 0.2738797  0.24491711
#   0.5025205  0.2868495  0.43937305 0.39200476 0.25906956 0.17595544
#   0.21427746 0.22379903 0.12608165 0.22432768 0.12498797 0.22512126
#   0.4054885  0.30221152 0.17776157 0.1867644  0.23640513 0.20869172
#   0.08848875 0.13782087 0.07564381 0.3594215  0.41381288 0.38326633
#   0.18842325 0.03699233 0.07660156 0.21741824 0.14798386 0.22225949
#   0.28441986 0.09764518 0.15165658 0.17032434 0.13064854 0.17470203
#   0.15088776 0.24649552 0.03097892 0.19246826 0.1252422  0.02578299
#   0.19177575 0.17641214 0.22214594 0.17531888 0.19923103 0.29253462
#   0.21167645 0.05933196 0.29577303 0.0954323  0.18022414 0.41523784
#   0.4112635  0.32787424]]
# ...
# [[0.2521674  0.39166057 0.2223255  0.2642094  0.24849999 0.10507098
# ...

# %%
tes_embed = model.encode(test, batch_size = 8, show_progress_bar = True)
np.shape(tes_embed)
#thislength=3
for i in range(len(Tokenized_Stripped)):
  text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  np.shape(text_embeddings)
  sumed =0
  if len(tes_embed)>len(text_embeddings):
    length = len(text_embeddings)
  else:
    length = len(tes_embed)
  for k in range(length):
    for t in range(len(text_embeddings)):
      simi = cosine_similarity(tes_embed[k].reshape(1,-1),text_embeddings[k][t].reshape(1,-1))
      sumed = simi+sumed
  print(sumed/len(text_embeddings))
# Out:
# ...
# [[1.4324324]]
# ...
# [[-0.25114155]]
# ...
# [[-0.6862745]]
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-04fc9d83e2f7> in <module>()
#      12   for k in range(length):
#      13     for t in range(len(text_embeddings)):
# ---> 14       simi = cosine_similarity(tes_embed[k].reshape(1,-1),text_embeddings[k][t].reshape(1,-1))
#      15       sumed = simi+sumed
#      16   print(sumed/len(text_embeddings))
#
# IndexError: index 768 is out of bounds for axis 0 with size 768

# %%
print(len(database))
# Out:
# 582049

# %%
print(main_embeddings)
# Out:
# [-6.61817670e-01  6.38987362e-01 -1.02570966e-01 -3.73195767e-01
#  -4.34944808e-01 -3.52733284e-01  9.97304440e-01  8.20522159e-02
#   8.03084135e-01 -4.16949868e-01  3.71349789e-02  3.15745056e-01
#   3.04366678e-01  7.50192165e-01  2.39483148e-01  7.85289347e-01
#  -3.14035147e-01 -2.47638583e-01 -1.48447260e-01 -9.38316528e-03
#   1.50412381e-01 -1.78609602e-02  5.47908664e-01  7.18791783e-01
#   1.05078959e+00  4.32738960e-01  3.96034479e-01 -4.02998060e-01
#  -1.22243190e+00  5.24881966e-02 -1.81545317e-01 -2.69827731e-02
#  -6.36421680e-01 -2.10296944e-01 -9.49822962e-02  8.37351322e-01
#  -9.14114490e-02  3.41308653e-01  2.04034805e-01 -3.92201990e-02
#  -2.15424269e-01 -3.64960581e-01  6.64936662e-01  5.66494986e-02
#  -1.28374743e+00 -6.47607148e-01 -4.37002718e-01  1.14854217e+00
#   7.75625348e-01 -3.81231755e-01  3.81508142e-01  6.80914521e-01
#   1.04670048e+00  4.85473782e-01 -3.77297968e-01  2.68739998e-01
# ...

# %%
databasedict ={}

# %% [markdown]
# #Trial user 1

# %%
textCit = read_file("/content/Project_info/citation.txt")
sentencesCit=sent_tokenize(textCit)

# %%
text_embedCit = model.encode(textCit, batch_size = 8, show_progress_bar = True)

# %%
np.shape(Atten_embeddings2)
for i in range(len(Tokenized_Stripped)):
  text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  np.shape(text_embeddings)
  sumed =0
  if len(Atten_embeddings2)>len(text_embeddings):
    length = len(text_embeddings)
  else:
    length = len(Atten_embeddings2)
  for k in range(length):
    simi = cosine_similarity(Atten_embeddings2[k].reshape(1, -1),text_embeddings[k].reshape(1, -1))
    sumed = simi+sumed
  print((sumed/length)*100)
# Out:
# ...
# [[30.484222]]
# ...
# [[43.372646]]
# ...
# [[36.28237]]
# ...
# [[37.37336]]
# ...
# [[40.878452]]
# ...
# [[38.320244]]
# ...
# [[39.71659]]
# ...
# [[41.741974]]
# ...
# [[36.14677]]
# ...
# [[32.702488]]
# ...
# [[100.]]
# ...
# [[39.33419]]

# %%
test="Recurrent Neural Networks (RNNs) have long been the dominant architecture in sequence-to-sequence learning. RNNs, however, are inherently sequential models that do not allow parallelization of their computations. Transformers are emerging as a natural alternative to standard RNNs, replacing recurrent computations with a multi-head attention mechanism. In this paper, we propose the SepFormer, a novel RNN-free"

# %%
print(tes_embed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-8f47ed4a845e> in <module>()
# ----> 1 print(tes_embed)
#
# NameError: name 'tes_embed' is not defined

# %%
tes_embed = model.encode(test, batch_size = 8, show_progress_bar = True)
np.shape(tes_embed)
#thislength=3
for i in range(len(Tokenized_Stripped)):
  text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  np.shape(text_embeddings)
  sumed =0
  if len(tes_embed)>len(text_embeddings):
    length = len(text_embeddings)
  else:
    length = len(tes_embed)
  for k in range(length):
    for t in range(len(text_embeddings)):
      simi = cosine_similarity(tes_embed[k].reshape(1,-1),text_embeddings[k][t].reshape(1,-1))
      sumed = simi+sumed
  print(sumed/len(text_embeddings))
# Out:
# ...
# [[-0.8466077]]
# ...
# [[0.06122449]]
# ...
# [[-0.12544803]]
# ...
# [[0.47368422]]
# ...
# [[1.4285715]]
# ...
# [[0.20833333]]
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-4a9534c6314d> in <module>()
#      12   for k in range(length):
#      13     for t in range(len(text_embeddings)):
# ---> 14       simi = cosine_similarity(tes_embed[k].reshape(1,-1),text_embeddings[k][t].reshape(1,-1))
#      15       sumed = simi+sumed
#      16   print(sumed/len(text_embeddings))
#
# IndexError: index 768 is out of bounds for axis 0 with size 768

# %%
tes_embed = model.encode(test, batch_size = 8, show_progress_bar = True)

# %%
np.shape(tes_embed)
# Out:
# (768,)

# %%
print(tes_embed)
# Out:
# [-1.90909475e-01  2.86347687e-01  7.55041242e-01  1.10606469e-01
#  -1.06006309e-01 -1.03744256e+00  1.14681244e+00  1.56690910e-01
#   5.99125445e-01  1.36836618e-01 -6.34208247e-02  1.07847738e+00
#  -2.63955057e-01  5.20655155e-01 -7.51057625e-01  2.35116050e-01
#   2.11993322e-01 -7.10316122e-01  2.87952691e-01 -1.84008121e-01
#  -4.29432392e-01 -2.83404678e-01 -3.66143882e-01  7.04268813e-01
#   6.35808527e-01  1.48651108e-01  2.84102321e-01 -7.10724294e-01
#  -5.55356383e-01  5.68372369e-01 -9.96455848e-02  6.64317846e-01
#   1.86105311e-01 -1.77283794e-01  2.72280306e-01  1.02039516e+00
#   4.96231169e-01  8.61874372e-02  1.14951104e-01  1.77068502e-01
#   7.16786146e-01 -2.98934102e-01 -2.80096810e-02 -2.35481620e-01
#  -1.04228187e+00  9.29936320e-02  3.83016691e-02  4.44195360e-01
#   1.77863836e-01 -8.95455897e-01 -1.37124896e+00  4.81803507e-01
#   6.06530547e-01  8.57123807e-02 -3.19107264e-01 -6.00900888e-01
# ...

# %%
np.shape(main_embeddings)
# Out:
# (768,)

# %%
np.shape(main_embeddings)
#thislength=3
#for i in range(len(Tokenized_Stripped)):
 # text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
 # np.shape(text_embeddings)
sumed =0
length = len(tes_embed)
  for k in range(length):
    for t in range(len(text_embeddings)):
      simi = cosine_similarity(tes_embed[k].reshape(1,-1),text_embeddings[k][t].reshape(1,-1))
      sumed = simi+sumed
  print(sumed/len(text_embeddings))
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-9e0bcf21f159> in <module>()
#       2 #thislength=3
#       3 for i in range(len(Tokenized_Stripped)):
# ----> 4   text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
#       5   np.shape(text_embeddings)
#       6   sumed =0
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     192
#     193             with torch.no_grad():
# --> 194                 out_features = self.forward(features)
#     195
#     196                 if output_value == 'token_embeddings':
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
# ...

# %%
print(sumed)
# Out:
# [[10.]]

# %%
for t in range(len(text_embeddings)):
      simi = cosine_similarity(tes_embed[k].reshape(1,-1),text_embeddings[k][t].reshape(1,-1))
sumed = simi+sumed

# %%
print(sumed)
# Out:
# [[1.]]

# %%
print(text_embeddings[k].reshape(1, -1))
# Out:
# [[-2.17647254e-01  6.35728776e-01  4.63638961e-01  1.83157206e-01
#    9.29833502e-02 -1.09662533e+00  1.88871264e-01  7.73869932e-01
#    5.39951086e-01 -6.65277898e-01  5.95942795e-01  4.98301595e-01
#    6.68760717e-01  1.63072824e-01 -2.88751811e-01  5.28785884e-01
#   -3.62662137e-01 -2.21896470e-01  3.54223698e-01 -3.64885122e-01
#   -4.93986130e-01 -6.47365272e-01  2.92527616e-01  8.38081777e-01
#    1.11425996e+00  8.06962192e-01  2.25735396e-01 -8.43836188e-01
#   -4.19089675e-01  3.50038737e-01 -4.39638257e-01  3.03118527e-01
#   -4.21430208e-02 -4.12565082e-01  8.03538620e-01  9.08600926e-01
#    5.81256211e-01  3.73905212e-01 -4.50405896e-01 -3.78674679e-02
#    5.73290288e-01 -1.21008384e+00  1.80170670e-01 -2.91935831e-01
#   -1.15487313e+00  9.86033604e-02 -8.18603039e-01  1.24152815e+00
#    2.12699816e-01 -8.54278564e-01 -1.39713967e+00  6.43336833e-01
#    2.11666569e-01 -1.74023196e-01 -3.36562008e-01 -5.57838939e-02
# ...

# %%
tes_embed = model.encode(test, batch_size = 8, show_progress_bar = True)
np.shape(tes_embed)
#thislength=3
for i in range(len(Tokenized_Stripped)-5):
  text_embeddings = model.encode(Tokenized_Stripped[i], batch_size = 8, show_progress_bar = True)
  np.shape(text_embeddings)
  sumed =0
  if len(Atten_embeddings2)>len(text_embeddings):
    length = len(text_embeddings)
  else:
    length = len(Atten_embeddings2)
  for k in range(length):
    for t in range(len(text_embeddings)):
      simi = cosine_similarity(tes_embed[k].reshape(1,-1),text_embeddings[k][t].reshape(1,-1))
      sumed = simi+sumed
  print(sumed/len(text_embeddings))
# Out:
# ...
# [[-0.7463127]]
# ...
# [[0.06122449]]
# ...
# [[-0.48387095]]
# ...
# [[0.47368422]]
# ...
# [[1.4285715]]
# ...
# [[0.20833333]]
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-e5369bd9414a> in <module>()
#      12   for k in range(length):
#      13     for t in range(len(text_embeddings)):
# ---> 14       simi = cosine_similarity(tes_embed[k].reshape(1,-1),text_embeddings[k][t].reshape(1,-1))
#      15       sumed = simi+sumed
#      16   print(sumed/len(text_embeddings))
#
# IndexError: index 768 is out of bounds for axis 0 with size 768
